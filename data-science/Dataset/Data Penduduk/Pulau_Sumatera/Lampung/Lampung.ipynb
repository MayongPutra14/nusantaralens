# %%
import pandas as pd

data = pd.read_csv(
    "Data_Lampung_Kotor.csv"
)

display(data.tail())


total_laki = 4857470
total_perempuan = 4665440


total_keseluruhan = (
    total_laki + total_perempuan
)

# dataframe final
df_final = pd.DataFrame([{
    'laki_laki': total_laki,
    'perempuan': total_perempuan,
    'total_keseluruhan': total_keseluruhan
}])

display(df_final)

# simpan csv
df_final.to_csv(
    'jumlah_penduduk_lampung.csv',
    index=False
)

# simpan json
df_final.to_json(
    'jumlah_penduduk_lampung.json',
    orient='records',
    indent=4
)
# Out:
#    Kelompok Umur (75+)  \
# 14               60-64
# 15               65-69
# 16               70-74
# 17                 75+
# 18              Jumlah
#
#    Jumlah Penduduk Menurut Kelompok Umur dan Jenis Kelamin (ribu jiwa)  \
# 14                                             200.07
# 15                                             149.24
# 16                                             101.32
# 17                                              96.35
# 18                                            4857.47
#
#    Unnamed: 2
# 14     193.47
# 15     142.73
# 16      98.25
# 17     100.21
# 18    4665.44
#    laki_laki  perempuan  total_keseluruhan
# 0    4857470    4665440            9522910
