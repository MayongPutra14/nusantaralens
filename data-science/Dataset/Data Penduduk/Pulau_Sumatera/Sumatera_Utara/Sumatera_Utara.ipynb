# %%
import pandas as pd

df = pd.read_csv("Data_SumateraUtara_Kotor.csv")
print(df.head())
# Out:
#      Kabupaten Kota  \
# 0               NaN
# 1               NaN
# 2    Sumatera Utara
# 3              Nias
# 4  Mandailing Natal
#
#   Jumlah Penduduk menurut Jenis Kelamin dan Kabupaten/Kota (Jiwa) Unnamed: 2
# 0                                          Perempuan               Laki-Laki
# 1                                               2025                    2025
# 2                                            7862993                 7922846
# 3                                              80513                   77000
# 4                                             257321                  256215

# %%
import pandas as pd


data = pd.read_csv("Data_SumateraUtara_Kotor.csv")

df = data.copy()

df_jumlah = df[
    df.iloc[:,0].astype(str).str.contains(
        'Sumatera Utara',
        na=False,
        case=False
    )
]

total_laki = int(
    pd.to_numeric(
        df_jumlah.iloc[0,1],
        errors='coerce'
    )
)

total_perempuan = int(
    pd.to_numeric(
        df_jumlah.iloc[0,2],
        errors='coerce'
    )
)

total_penduduk = total_laki + total_perempuan

# dataframe final
df_final = pd.DataFrame([{
    'laki_laki': total_laki,
    'perempuan': total_perempuan,
    'total_keseluruhan': total_penduduk
}])

display(df_final)

# simpan csv
df_final.to_csv(
    'sumatera_utara.csv',
    index=False
)

# simpan json
df_final.to_json(
    'jumlah_penduduk_sumatera_utara.json',
    orient='records',
    indent=4
)
# Out:
#    laki_laki  perempuan  total_keseluruhan
# 0    7862993    7922846           15785839
