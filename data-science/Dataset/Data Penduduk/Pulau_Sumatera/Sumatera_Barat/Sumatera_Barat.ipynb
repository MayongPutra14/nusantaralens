# %%
import pandas as pd

df = pd.read_csv("Data_Sumatera_Barat_Kotor.csv")
print(df.head())
# Out:
#             Kabupaten/Kota  \
# 0                      NaN
# 1                      NaN
# 2  Kab. Kepulauan Mentawai
# 3     Kab. Pesisir Selatan
# 4               Kab. Solok
#
#   [Proyeksi 2020-2035] Jumlah Penduduk Menurut Kabupaten/Kota dan Jenis Kelamin di Provinsi Sumatera Barat (Ribu Jiwa)  \
# 0                                          Laki-Laki
# 1                                               2025
# 2                                              48.58
# 3                                             271.71
# 4                                              208.9
#
#   Unnamed: 2
# 0  Perempuan
# 1       2025
# 2      45.46
# 3     268.68
# 4     206.54

# %%
import pandas as pd


data = pd.read_csv("Data_Sumatera_Barat_Kotor.csv")

df = data.copy()

df_jumlah = df[
    df.iloc[:,0].astype(str).str.contains(
        'Sumatera Barat',
        na=False,
        case=False
    )
]

total_laki = int(
    pd.to_numeric(
        df_jumlah.iloc[0,1],
        errors='coerce'
    )
)

total_perempuan = int(
    pd.to_numeric(
        df_jumlah.iloc[0,2],
        errors='coerce'
    )
)

total_penduduk = total_laki + total_perempuan

# dataframe final
df_final = pd.DataFrame([{
    'laki_laki': total_laki,
    'perempuan': total_perempuan,
    'total_keseluruhan': total_penduduk
}])

display(df_final)

# simpan csv
df_final.to_csv(
    'jumlah_penduduk_sumatera_barat.csv',
    index=False
)

# simpan json
df_final.to_json(
    'jumlah_penduduk_sumatera_barat.json',
    orient='records',
    indent=4
)
# Out:
#    laki_laki  perempuan  total_keseluruhan
# 0       2979       2934               5913
