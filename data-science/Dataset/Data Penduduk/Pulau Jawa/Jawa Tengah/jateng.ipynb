# %%
import pandas as pd
import json

# %%
data = pd.read_csv('Data Jawa Tengah Kotor.csv')
display(data)
display(data.info())
# Out:
#    Kelompok Umur  Penduduk (Laki-Laki) (Ribu)  Penduduk (Perempuan) (Ribu)  \
# 0         4/1/00                      1453486                      1395492
# 1         5/9/01                      1378005                      1314670
# 2       10/14/01                      1388617                      1324616
# 3          15-19                      1434037                      1349663
# 4          20-24                      1453872                      1371580
# 5          25-29                      1488450                      1405197
# 6          30-34                      1478667                      1407466
# 7          35-39                      1457127                      1406076
# 8          40-44                      1404285                      1376799
# 9          45-49                      1344073                      1352647
# 10         50-54                      1229032                      1260829
# ...

# %%
df = data.copy()
df = df.drop(columns=['Penduduk (Laki-Laki + Perempuan) (Ribu)'])
df_jumlah = df[df['Kelompok Umur'].str.contains('Jumlah/Total', na=False, case=False)]
total_laki = int(pd.to_numeric(df_jumlah['Penduduk (Laki-Laki) (Ribu)'].iloc[0]))
total_perempuan = int(pd.to_numeric(df_jumlah['Penduduk (Perempuan) (Ribu)'].iloc[0]))
total_penduduk = total_laki + total_perempuan

df_final = pd.DataFrame([{
    'laki_laki': total_laki,
    'perempuan': total_perempuan,
    'total_keseluruhan': total_penduduk
}])

display(df_final)
# Out:
#    laki_laki  perempuan  total_keseluruhan
# 0   19203434   19030499           38233933

# %%
df_final.to_csv('jumlah_penduduk_jawa_tengah.csv', index=False)
df_final.to_json('jumlah_penduduk_jawa_tengah.json', orient='records')
