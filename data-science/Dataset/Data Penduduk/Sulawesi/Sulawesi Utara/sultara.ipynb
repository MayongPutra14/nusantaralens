# %%
import pandas as pd
import json

# %%
data = pd.read_csv('Data Sulawesi Utara Kotor.csv')
display(data)
display(data.info())
# Out:
#    Kelompok Umur  Penduduk (Laki-Laki) (Ribu)  Penduduk (Perempuan) (Ribu)  \
# 0         4/1/00                        103.0                         98.8
# 1         5/9/01                        101.0                         96.7
# 2       10/14/01                        105.1                        100.5
# 3          15-19                        105.0                         97.7
# 4          20-24                        105.8                         98.3
# 5          25-29                        109.2                        101.7
# 6          30-34                        107.0                        100.1
# 7          35-39                        102.4                         95.6
# 8          40-44                         99.0                         92.6
# 9          45-49                         96.7                         91.3
# 10         50-54                         88.9                         84.8
# 11         55-59                         79.8                         77.4
# 12         60-64                         66.0                         65.7
# 13         65-69                         50.2                         51.8
# 14         70-74                         34.2                         36.9
# 15           75+                         35.0                         43.3
# 16  Jumlah/Total                       1388.2                       1333.2
#
#     Penduduk (Laki-Laki + Perempuan) (Ribu)
# 0                                     201.7
# 1                                     197.8
# 2                                     205.6
# 3                                     202.7
# 4                                     204.2
# 5                                     210.8
# 6                                     207.1
# 7                                     198.0
# 8                                     191.6
# 9                                     188.0
# 10                                    173.6
# 11                                    157.2
# 12                                    131.7
# 13                                    102.1
# 14                                     71.1
# 15                                     78.3
# 16                                   2721.4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 4 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Kelompok Umur                            17 non-null     object
#  1   Penduduk (Laki-Laki) (Ribu)              17 non-null     float64
#  2   Penduduk (Perempuan) (Ribu)              17 non-null     float64
#  3   Penduduk (Laki-Laki + Perempuan) (Ribu)  17 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 676.0+ bytes
# None

# %%
df = data.copy()
df = df.drop(columns=['Penduduk (Laki-Laki + Perempuan) (Ribu)'])
df_jumlah = df[df['Kelompok Umur'].str.contains('Jumlah/Total', na=False, case=False)]
total_laki = int(pd.to_numeric(df_jumlah['Penduduk (Laki-Laki) (Ribu)'].iloc[0])*1000)
total_perempuan = int(pd.to_numeric(df_jumlah['Penduduk (Perempuan) (Ribu)'].iloc[0])*1000)
total_penduduk = total_laki + total_perempuan

df_final = pd.DataFrame([{
    'laki_laki': total_laki,
    'perempuan': total_perempuan,
    'total_keseluruhan': total_penduduk
}])

display(df_final)
# Out:
#    laki_laki  perempuan  total_keseluruhan
# 0    1388200    1333200            2721400

# %%
df_final.to_csv('jumlah_penduduk_sulawesi_utara.csv', index=False)
df_final.to_json('jumlah_penduduk_sulawesi_utara.json', orient='records')
