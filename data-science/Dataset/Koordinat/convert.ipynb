# %%
import pandas as pd
import json

# %%
df = pd.read_csv('Koordinat_NusantaraLens.csv')
display(df)

df.to_json('Koordinat.json')
# Out:
#                 Daerah  Latitude  Longitude
# 0                 Aceh    4.6951    96.7494
# 1           Yogyakarta   -7.8754   110.4262
# 2  Nusa Tenggara Timur   -8.6574   121.0794
